# %% [markdown]
# 作業1：
#
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb
#
# 完成 Mean Squared Error 的函式。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """   
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp) ** 2) / len(y) #加入**2平方
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 202.356
# The Mean absolute error is 10.746

# %% [markdown]
# 作業2：申論題目可直接將答案回覆在HW檔案裡面，Jupyter notebook可直接編輯文字。
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 這組資料想解決的問題如何評估

# %% [markdown]
# Ans：
# 1.經由人資分析：數據科學家的工作變動的資料或許可以作為面試時知道資方想找尋何種人才的依據。
# 2.https://www.kaggle.com/arashnic/hr-analytics-job-change-of-data-scientists
# test set : credentials/demographics/experience features
# 3.csv格式檔
# 4.公司想知道在培訓或尋找新工作後，其中哪些候選人真的想為公司工作，
# 因為這有助於降低成本和時間，並減少培訓或計劃課程和候選人類別的質與量。

# %% [markdown]
# 作業3：申論題目可直接將答案回覆在HW檔案裡面，Jupyter notebook可直接編輯文字。
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# Ans:
# 1.假設有自由載客車隊過去3年的資料(包含司機，乘客，乘坐日期時間，時數，地理位置,氣候...等)
# 提升業績的指標:
# a.在相同時間點,同一司機的載客人數(個別)
# b.後來收集數據與過去數據時段(月，季，年)比對
#
# 2.利用APP線上登入駕駛員與乘客(會員)，GPS定位。
# 3.資料型態應該為一時序性DATA，收集的資料只能是過去式。
# 4.或許可以用(long short-term memory, LSTM)分析，Recurrent Neural Network類神經網路， 去作未來趨勢預測，如跨年時段，特殊節日。
# 某路段會出現大量乘客需求,或是某駕駛員與許多乘客關聯度高,那這位駕駛員就是車隊需要惜才保留的,以免流失客戶，
